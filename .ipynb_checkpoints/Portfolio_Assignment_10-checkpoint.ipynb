# %%
import pandas as pd
pokemon = pd.read_csv('pokedex_(Update_04.21).csv', sep=',')

# %%
pokemon.plot(kind='scatter', x='weight_kg', y='height_m')
# Out:
# <AxesSubplot:xlabel='weight_kg', ylabel='height_m'>

# %% [markdown]
# Uit de scatterplot is te merken dat er enigzins een correlatie te zien is tussen het gewicht en de lengte van een Pokemon. Je ziet dat er een lichte stijging is in het gewicht, wanneer de pokemon langer wordt.
