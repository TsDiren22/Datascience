# %%
import pandas as pd
import seaborn as sns
pokemon = pd.read_csv('pokedex_(Update_04.21).csv', sep=',')
pokemon['type_2'].fillna('None').dropna()
pokemon
# Out:
#      Unnamed: 0  pokedex_number                  name german_name  \
# 0             0               1             Bulbasaur     Bisasam
# 1             1               2               Ivysaur   Bisaknosp
# 2             2               3              Venusaur    Bisaflor
# 3             4               4            Charmander    Glumanda
# 4             5               5            Charmeleon     Glutexo
# ..          ...             ...                   ...         ...
# 992        1040             896             Glastrier    Polaross
# 993        1041             897             Spectrier  Phantoross
# 994        1042             898               Calyrex   Coronospa
# 995        1043             898     Calyrex Ice Rider   Coronospa
# 996        1044             898  Calyrex Shadow Rider   Coronospa
#
#            japanese_name  generation         status              species  \
# 0    フシギダネ (Fushigidane)           1         Normal         Seed Pokémon
# ...

# %%
pokemon.plot(kind='scatter', x='weight_kg', y='height_m')
# Out:
# <AxesSubplot:xlabel='weight_kg', ylabel='height_m'>

# %% [markdown]
# Uit de scatterplot is te merken dat er enigzins een correlatie te zien is tussen het gewicht en de lengte van een Pokemon. Je ziet dat er een lichte stijging is in het gewicht, wanneer de pokemon langer wordt.

# %%
pokemon.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# C:\Users\diren\AppData\Local\Temp/ipykernel_15364/2071621101.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   pokemon.corr().style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# <style type="text/css">
# ...

# %%
pokemon.plot(kind='scatter', x='total_points', y='base_experience')
# Out:
# <AxesSubplot:xlabel='total_points', ylabel='base_experience'>
